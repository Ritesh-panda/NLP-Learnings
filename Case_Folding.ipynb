# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-panda/NLP-Learnings/blob/main/Case_Folding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
txt="Hello, Welcome to The wORlD"
print(txt)
# Out:
# Hello, Welcome to The wORlD

# %%
x=txt.casefold()

# %%
print(x)
# Out:
# hello, welcome to the world

# %%
y=txt.lower()
print(y)
# Out:
# hello, welcome to the world
