# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-panda/NLP-Learnings/blob/main/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
s="we will be forming a tokenization here. For this sentence we will add $ ^ * % (  % ) %^ & @ !. and many more things are added"
word_tokenize(s)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['we',
#  'will',
#  'be',
#  'forming',
#  'a',
#  'tokenization',
#  'here',
#  '.',
#  'For',
#  'this',
#  'sentence',
#  'we',
#  'will',
#  'add',
#  '$',
#  '^',
#  '*',
#  '%',
#  '(',
#  '%',
#  ')',
#  '%',
#  '^',
#  '&',
#  '@',
#  '!',
#  '.',
#  'and',
#  'many',
#  'more',
#  'things',
#  'are',
#  'added']

# %%
sent_tokenize(s)
# Out:
# ['we will be forming a tokenization here.',
#  'For this sentence we will add $ ^ * % (  % ) %^ & @ !.',
#  'and many more things are added']
